# %% [markdown]
# Reto 13

# %%
# Punto 1.  Pide al usuario ingresar diccionario. 

def crearDiccionario(*args): # Definimos la función. 
    global dic # Declaramos la variable "dic" como una variable global. 
    dic = {} # Establecemos variable con diccionaro vacio. 
    for i in range(longitudDiccionario): # Itera desde 0 hasta la longitud del diccionario. 
        # Por cada iteración pide: 
        key = (input("Ingrese la llave del diccionario: ")) # Ingresar "key"
        value = (input("Ingrese el valor del diccionaro: ")) # Ingresar "value"
        dic.update({key:value}) # Los agrega al diccionario. 
    return dic # Devuelve el diccionario. 

def valoresEnOrden(*args): # defenimos la función. 
    valores = list(dic.values())  # Agrega los "values" del diccionario a una lista.
    valores.sort(reverse=False) # Organiza la lista en orden ascentende alfabeticamente. 
    for i in valores: # Itera los valores de la lista. 
        print(i) # Los imprime
    return ("La lista de los valores organizados del diccionario es: ", valores) # Devuleve. 
    



if __name__ == "__main__": # Inicializa las funciones. 
    longitudDiccionario = int(input("Ingrese la logitud del diccionario: ")) # Pide al usuario ingresar variable. 
    print("El diccionario ingresado fue: ", crearDiccionario(longitudDiccionario)) # Imprime. 
    print(valoresEnOrden(dic))
# Out:
# El diccionario ingresado fue:  {'Bogota': 'Colombia', 'Tokyo ': 'Japon', 'Moscu': 'Rusia', 'Caracas ': 'Venezuela', 'Buenos Aires ': 'Argentina'}
# Argentina
# Colombia
# Japon
# Rusia
# Venezuela
# ('La lista de los valores del diccionario es: ', ['Argentina', 'Colombia', 'Japon', 'Rusia', 'Venezuela'])

# %%
# Punto 1.  Diccionario establecido. 

dic = {'Bogota': 'Colombia', 'Tokyo ': 'Japon', 'Moscu': 'Rusia', 'Caracas ': 'Venezuela', 'Buenos Aires ': 'Argentina'} # Diccionario. 

def valoresEnOrden(*args): # defenimos la función. 
    valores = list(dic.values())  # Agrega los "values" del diccionario a una lista.
    valores.sort(reverse=False) # Organiza la lista en orden ascentende alfabeticamente. 
    for i in valores: # Itera los valores de la lista. 
        print(i) # Los imprime
    return ("La lista de los valores organizados del diccionario es: ", valores) # Devuleve. 
    



if __name__ == "__main__": # Inicializa las funciones. 
    print(valoresEnOrden(dic)) #Imprime
# Out:
# Argentina
# Colombia
# Japon
# Rusia
# Venezuela
# ('La lista de los valores organizados del diccionario es: ', ['Argentina', 'Colombia', 'Japon', 'Rusia', 'Venezuela'])

# %%
# Punto 2. Pide ingresar al usuario los diccionarios. 

def crearDiccionario(*args): # Definimos la función. 
    global dic1 # Declaramos la variable "dic" como una variable global. 
    dic1 = {} # Establecemos variable con diccionaro vacio. 
    for i in range(longitudDiccionario1): # Itera desde 0 hasta la longitud del diccionario. 
        # Por cada iteración pide: 
        key = (input("Ingrese la llave del primer diccionario: ")) # Ingresar "key"
        value = (input("Ingrese el valor del primer diccionaro: ")) # Ingresar "value"
        dic1.update({key:value}) # Los agrega al diccionario. 
    return dic1 # Devuelve el diccionario. 

def crearDiccionario2(*args): 
    global dic2
    dic2 = {} 
    for i in range(longitudDiccionario2): 
        key = (input("Ingrese la llave del segundo diccionario: ")) 
        value = (input("Ingrese el valor del segundo diccionaro: ")) 
        dic2.update({key:value}) 
    return dic2 

def mezclarDiccionarios(*args): # Definimos función. 
    dic3 = {} # Creamos diccionario vacio. 
    if dic1 == dic2: # Condición: Que los diccionarios 1 y 2 sean igulaes. 
        dic3 = dic1.copy() # Si cumple la condición: Copia el diccionario 1 en el 3. 
    
    else: # Si no cumple la condición. 
        dic3 = dic2.copy() # Copia el diccionaro 2 en el 3. 
        for keys, values in dic1.items(): # Itera tanto las llaves como los valores del diccionario 1. 
            dic3.update({keys:values}) # Actualiza. 
            
    return(dic3) # Devuelve. 



if __name__ == "__main__": # Inicializa las funciones. 
    longitudDiccionario1 = int(input("Ingrese la logitud del primer diccionario: ")) # Pide al usuario ingresar variable. 
    longitudDiccionario2 = int(input("Ingrese la logitud del segundo diccionario: ")) # Pide al usuario ingresar variable. 
    print("El primer diccionario ingresado fue: ", crearDiccionario(longitudDiccionario1)) # Imprime. 
    print("El segundo diccionario ingresado fue: ", crearDiccionario2(longitudDiccionario2)) 
    print("La mezcla de los diccionarios ingresados es: ", mezclarDiccionarios(dic1, dic2))
# Out:
# El primer diccionario ingresado fue:  {'Alemania': 'Berlin', 'Suecia': 'Estocolmo', 'Colombia': 'Bogotá'}
# El segundo diccionario ingresado fue:  {'Colombia': 'Medellin', 'China': 'Pekin', 'Vaticano': 'Vaticano', 'Venezuela': 'Caracas'}
# La mezcla de los diccionarios ingresados es:  {'Colombia': 'Bogotá', 'China': 'Pekin', 'Vaticano': 'Vaticano', 'Venezuela': 'Caracas', 'Alemania': 'Berlin', 'Suecia': 'Estocolmo'}

# %%
# Punto 2. Diccionarios Establecidos

dic1 = {'Alemania': 'Berlin', 'Suecia': 'Estocolmo ', 'Colombia': 'Bogotá'} # Diccionario. 
dic2 = {'Colombia': 'Medellin', 'China': 'Pekin', 'Vaticano': 'Vaticano', 'Venezuela': 'Caracas'}
dic3 = {}

def mezclarDiccionarios(*args): # Definimos función. 
    dic3 = {} # Creamos diccionario vacio. 
    if dic1 == dic2: # Condición: Que los diccionarios 1 y 2 sean igulaes. 
        dic3 = dic1.copy() # Si cumple la condición: Copia el diccionario 1 en el 3. 
    
    else: # Si no cumple la condición. 
        dic3 = dic2.copy() # Copia el diccionaro 2 en el 3. 
        for keys, values in dic1.items(): # Itera tanto las llaves como los valores del diccionario 1. 
            dic3.update({keys:values}) # Actualiza. 
            
    return(dic3) # Devuelve. 

if __name__ == "__main__": # Inicializa las funciones. 
    print("La mezcla de los diccionarios ingresados es: ", mezclarDiccionarios(dic1, dic2)) # Imprime.
# Out:
# La mezcla de los diccionarios ingresados es:  {'Colombia': 'Bogotá', 'China': 'Pekin', 'Vaticano': 'Vaticano', 'Venezuela': 'Caracas', 'Alemania': 'Berlin', 'Suecia': 'Estocolmo '}

# %%
# Punto 3. 

import json # Importamos la función. 
import requests

# Establecemos variable con el Json string. 
jsonString = ''' 
{
	"jadiazcoronado":{
		"nombres": "Juan Antonio",
		"apellidos": "Diaz Coronado",
		"edad":19,
		"colombiano":true,
		"deportes":["Futbol","Ajedrez","Gimnasia"]
	},
	"dmlunasol":{
		"nombres": "Dorotea Maritza",
		"apellidos": "Luna Sol",
		"edad":25,
		"colombiano":false,
		"deportes":["Baloncesto","Ajedrez","Gimnasia"]
	}
}
'''

jsonString = json.dump()  

def extraerNombre(*args): 
    if deporte == "baloncesto" or deporte == "ajedrez" or deporte == "gimnasia" or deporte =="futbol": 
        json_data = jsonString.json()
        for key, value in json_data.items():
            print(key, ":", value)
        print(diccinarioJson)
    else: 
        print("Deporte no encontrado. Por favor ingrese otro deporte")



if __name__ == "__main__": # Inicializa las funciones. 
    deporte = str(input("Ingrese el deporte en minúsculas: "))
    print(extraerNombre(deporte, diccinarioJson))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 26
#       6 # Establecemos variable con el Json string.
#       7 jsonString = '''
#       8 {
#       9 	"jadiazcoronado":{
#    (...)
#      23 }
#      24 '''
# ---> 26 jsonString = json.dump()
#      28 def extraerNombre(*args):
#      29     if deporte == "baloncesto" or deporte == "ajedrez" or deporte == "gimnasia" or deporte =="futbol":
#
# TypeError: dump() missing 2 required positional arguments: 'obj' and 'fp'

# %%
# Punto 3. 

import json # Importamos la función. 
import requests

# Guardamos diccionario en variable. 
archivo ={
	"jadiazcoronado":{
		"nombres": "Juan Antonio",
		"apellidos": "Diaz Coronado",
		"edad":19,
		"colombiano":True,
		"deportes":["Futbol","Ajedrez","Gimnasia"]
	},
	"dmlunasol":{
		"nombres": "Dorotea Maritza",
		"apellidos": "Luna Sol",
		"edad":25,
		"colombiano":False,
		"deportes":["Baloncesto","Ajedrez","Gimnasia"]
	}
}

file = open('archivo.json', 'w') # Creamos archivo tipo JSON, con el 'w' lo escribe en la variable.  
json.dump(archivo, file) # Almacena en el archivo generado. 


diccionario = json.load(file)
print(diccionario)


file.close() # Cierra el archivo.
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[160], line 28
#      24 file = open('archivo.json', 'w') # Creamos archivo tipo JSON, con el 'w' lo escribe en la variable.
#      25 json.dump(archivo, file) # Almacena en el archivo generado.
# ---> 28 diccionario = json.load(file)
#      29 print(diccionario)
#      32 file.close() # Cierra el archivo.
#
# File c:\Users\andri\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
# ...

# %%
import json

archivo = {
    "jadiazcoronado": {
        "nombres": "Juan Antonio",
        "apellidos": "Diaz Coronado",
        "edad": 19,
        "colombiano": True,
        "deportes": ["Futbol", "Ajedrez", "Gimnasia"]
    },
    "dmlunasol": {
        "nombres": "Dorotea Maritza",
        "apellidos": "Luna Sol",
        "edad": 25,
        "colombiano": False,
        "deportes": ["Baloncesto", "Ajedrez", "Gimnasia"]
    }
}

file = open('archivo.json', 'w')  # Creamos un archivo para escribir datos en este. 
json.dump(archivo, file)  # Guardamos el archivo como un archivo tipo JSON. 
file.close() # Cerramos el archivo. 

file = open('archivo.json', 'r')  # Abrimos el archivo en modo lectura
diccionario = json.load(file)  # Convierte el archivo tipo JSON a un diccionario en python. 
file.close() # Cerramos el archivo. 

def nombresDeporte(*args): # Definimos función. 
    for key, value in diccionario.items(): # Itera tanto las llaves con los valores del diccionario. 
        if deporte in value["deportes"]: # Condición.
            # Si el deporte ingresado por el usuario se encuentra dentro de la lista del "value" deportes. 
            nombres = value["nombres"] # Guarda variable del valor del "value"
            apellidos = value["apellidos"]
            print(nombres, apellidos) # Imprime
        else: # Si no cumple la condición. 
            print("El deporte ingresado no se encontro") # Imprime

def nombresEdad(*args): # Definimos función. 
    for key, value in diccionario.items():  # Itera tanto las llaves como los valores del diccionario. 
        edad = value["edad"] # Guarda en una variable el valor del "value"
        edad = int(edad) # Convierte dicho valor a un entero.
        if edadMinima <= edad <= edadMaxima: # Condición.
            # Que la edad se encuentre en el rango de edad ingresado por el usuario. 
            nombres = value["nombres"] # Guarda variable del valor del "value"
            apellidos = value["apellidos"]
            print(nombres, apellidos) # Imprime
        else: # Si no cumple la condición. 
            print("Las edades no se encuentran en el rango establecido.")  # Imprime. 


if __name__ == "__main__": # Inicializa las funciones.
    deporte = str(input("Ingrese el deporte: "))
    print("Nombres completos de personas que practican", deporte)
    print(nombresDeporte(diccionario, deporte))
    edadMinima = int(input("Ingrese la edad minima: "))
    edadMaxima = int(input("Ingrese edad maxima: "))
    print("Nombres completos de las personas que tienen el rango de edad entre", edadMinima, "-", edadMaxima)
    print(nombresEdad(edadMaxima, edadMinima, diccionario))
# Out:
# Nombres completos de personas que practican Ajedrez
# Juan Antonio Diaz Coronado
# Dorotea Maritza Luna Sol
# None
# Nombres completos de las personas que tienen el rango de edad entre 12 - 34
# Juan Antonio Diaz Coronado
# Dorotea Maritza Luna Sol
# None

# %%
# Punto 4. Codigo sin terminar. 

import json # Llamamos función.
import time  # Llamamos función. 
from datetime import datetime

# Cargar archivo
jsonString = '''
{\"dt\": {\"0\": 1685116800, \"1\": 1685203200, \"2\": 1685289600, \"3\": 1685376000, \"4\": 1685462400, \"5\": 1685548800, \"6\": 1685635200, \"7\": 1685721600}, \"sunrise\": {\"0\": 1685097348, \"1\": 1685183745, \"2\": 1685270143, \"3\": 1685356542, \"4\": 1685442942, \"5\": 1685529342, \"6\": 1685615743, \"7\": 1685702145}, \"sunset\": {\"0\": 1685143042, \"1\": 1685229458, \"2\": 1685315875, \"3\": 1685402291, \"4\": 1685488708, \"5\": 1685575124, \"6\": 1685661541, \"7\": 1685747958}, \"moonrise\": {\"0\": 1685118300, \"1\": 1685207460, \"2\": 1685296620, \"3\": 1685385720, \"4\": 1685474880, \"5\": 1685564220, \"6\": 1685653740, \"7\": 1685743500}, \"moonset\": {\"0\": 0, \"1\": 1685164320, \"2\": 1685253000, \"3\": 1685341560, \"4\": 1685430120, \"5\": 1685518740, \"6\": 1685607600, \"7\": 1685696640}, \"moon_phase\": {\"0\": 0.22, \"1\": 0.25, \"2\": 0.28
0\": 26.62, \"1\": 34.99, \"2\": 34.96, \"3\": 32.03, \"4\": 30.67, \"5\": 33.62, \"6\": 29.45, \"7\": 26.36}, \"feels_like.night\": {\"0\": 26.56, \"1\": 30.98, \"2\": 26.24, \"3\": 30.62, \"4\": 26.84, \"5\": 30.16, \"6\": 26.56, \"7\": 26.45}, \"feels_like.eve\": {\"0\": 26.85, \"1\": 32.49, \"2\": 30.94, \"3\": 31.8, \"4\": 31.51, \"5\": 33.17, \"6\": 32.64, \"7\": 31.18}, \"feels_like.morn\": {\"0\": 26.5, \"1\": 25.48, \"2\": 26.13, \"3\": 26.62, \"4\": 26.04, \"5\": 25.73, \"6\": 25.98, \"7\": 26.4}, \"date\": {\"0\": 1685098800000, \"1\": 1685185200000, \"2\": 1685271600000, \"3\": 1685358000000, \"4\": 1685444400000, \"5\": 1685530800000, \"6\": 1685617200000, \"7\": 1685703600000}, \"main\": {\"0\": \"Rain\", \"1\": \"Rain\", \"2\": \"Rain\", \"3\": \"Rain\", \"4\": \"Rain\", \"5\": \"Rain\", \"6\": \"Rain\", \"7\": \"Rain\"}, \"description\": {\"0\": \"lluvia moderada\", \"1\": \"lluvia ligera\", \"2\": \"lluvia moderada\", \"3\": \"lluvia ligera\", \"4\": \"lluvia moderada\", \"5\": \"lluvia ligera\", \"6\": \"lluvia ligera\", \"7\": \"lluvia ligera\"}, \"icono\": {\"0\": \"10d\", \"1\": \"10d\", \"2\": \"10d\", \"3\": \"10d\", \"4\": \"10d\", \"5\": \"10d\", \"6\": \"10d\", \"7\": \"10d\"}, \"alertPrecip\": {\"0\": \"X\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertAlertas\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertVelViento\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"X\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertTmpMax\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"X\", \"6\": \"-\", \"7\": \"-\"}, \"alertTmpMin\": {\"0\": \"-\", \"1\": \"X\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"recomendaciones\": {\"lluvias\": \"Realice una revisi\\u00f3n y limpieza a la red de desague y canales existentes ENTER8 Cuente con una estaci\\u00f3n de bombeo, que debe estar ubicada en el punto m\\u00e1s bajo del predio. Aseg\\u00farese de encender y probar el sistema de bombeo al menos una vez al mes y hacer un mantenimiento mensual al equipo de bombeoENTER8 Los productos alojados en zonas de almacenamiento deben mantenersen sobre estibas - estanterias, con el fin de que no entren en contacto directo con el agua.\", \"vientos\": \"-\", \"temperatura\": \"-\"}}
'''
data = json.loads(jsonString) # Convertimos el archivo JSON a un diccionario en Python. 

def indicadoralertAlertas(*args): 
    for key, value in data.items(): 
        if key == "alertAlertas": 
            for keys in value:
                alerta = value[keys]
                if alerta == "-":
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "NO habrá fenomeno climatico")
                    break

                else: 
                    print("En la fecha", fecha, "habrá fenomeno climatico")


def indicadoralertPrecip(*args): 
    for key, value in data.items(): 
        if key == "alertPrecip": 
            for keys in value:
                alerta = value[keys]
                if alerta == "-":
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "NO habrá fenomeno climatico")
                    break

                else: 
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "habrá fenomeno climatico")
                    break

def indicadoralertTmpMax(*args): 
    for key, value in data.items(): 
        if key == "alertTmpMax": 
            for keys in value:
                alerta = value[keys]
                if alerta == "-":
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "NO habrá fenomeno climatico")
                    break

                else: 
                    print("En la fecha", fecha, "habrá fenomeno climatico")

def indicadoralertTmpMin(*args): 
    for key, value in data.items(): 
        if key == "alertTmpMin": 
            for keys in value:
                alerta = value[keys]
                if alerta == "-":
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "NO habrá fenomeno climatico")
                    break

                else: 
                    print("En la fecha", fecha, "habrá fenomeno climatico")

def indicadoralertVelViento(*args): 
    for key, value in data.items(): 
        if key == "alertVelViento": 
            for keys in value:
                alerta = value[keys]
                if alerta == "-":
                    llavesEndt = data["dt"]  
                    for dias_llaves in llavesEndt: 
                        UTC = llavesEndt[dias_llaves]
                        ts = int(UTC)
                        fecha = (datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
                        print("En la fecha", fecha, "NO habrá fenomeno climatico")
                    break

                else: 
                    print("En la fecha", fecha, "habrá fenomeno climatico")

if __name__ == "__main__": # Inicializa las funciones.
    print("Indicador de alertas")
    print(indicadoralertAlertas(data))
    print(indicadoralertPrecip(data))
    print(indicadoralertTmpMax(data))
    print(indicadoralertTmpMin(data))
    print(indicadoralertVelViento(data))
# Out:
# Indicador de alertas
# En la fecha 2023-05-26 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-05-27 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-05-28 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-05-29 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-05-30 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-05-31 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-06-01 16:00:00 NO habrá fenomeno climatico
# En la fecha 2023-06-02 16:00:00 NO habrá fenomeno climatico
# None
# En la fecha 2023-05-26 16:00:00 habrá fenomeno climatico
# En la fecha 2023-05-27 16:00:00 habrá fenomeno climatico
# En la fecha 2023-05-28 16:00:00 habrá fenomeno climatico
# En la fecha 2023-05-29 16:00:00 habrá fenomeno climatico
# En la fecha 2023-05-30 16:00:00 habrá fenomeno climatico
# En la fecha 2023-05-31 16:00:00 habrá fenomeno climatico
", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"recomendaciones\": {\"lluvias\": \"Realice una revisi\\u00f3n y limpieza a la red de desague y canales existentes ENTER8 Cuente con una estaci\\u00f3n de bombeo, que debe estar ubicada en el punto m\\u00e1s bajo del predio. Aseg\\u00farese de encender y probar el sistema de bombeo al menos una vez al mes y hacer un mantenimiento mensual al equipo de bombeoENTER8 Los productos alojados en zonas de almacenamiento deben mantenersen sobre estibas - estanterias, con el fin de que no entren en contacto directo con el agua.\", \"vientos\": \"-\", \"temperatura\": \"-\"}}
'''
data = json.loads(jsonString) # Convertimos el archivo JSON a un diccionario en Python. 


print(data["alertAlertas"])
print(data["dt"])
# Out:
# {'0': '-', '1': '-', '2': '-', '3': '-', '4': '-', '5': '-', '6': '-', '7': '-'}
# {'0': 1685116800, '1': 1685203200, '2': 1685289600, '3': 1685376000, '4': 1685462400, '5': 1685548800, '6': 1685635200, '7': 1685721600}

# %%
# Punto 5. 

import json # Llama la función
import requests

url1 = 'https://catfact.ninja/fact'  # Variable que guarda el API
url2 = 'https://www.boredapi.com/api/activity'
url3 = 'https://official-joke-api.appspot.com/random_joke'

def datosAleatoriosDeGatos(*args): # Definimos función. 
    petición = requests.get(url1)  # Extrae la infromación del API
    respuesta = petición.text  # Devuelve el contenido como un string
    dict_data = petición.json()  # El ".json()" convierte la info del API y lo convierte en un archivo json/diccionario. 
    for key, value in dict_data.items(): # Itera el diccionario. 
            print(key, ":", value) # Imprime 
    return(respuesta) # Devuelve

def actividadeAleatorias(*args): 
    petición = requests.get(url2)
    respuesta = petición.text
    dict_data = petición.json()
    for key, value in dict_data.items():
            print(key, ":", value)
    return(respuesta)

def chistesAleatorios(*args): 
    petición = requests.get(url3)
    respuesta = petición.text
    dict_data = petición.json()
    for key, value in dict_data.items():
            print(key, ":", value)
    return(respuesta)

if __name__ == "__main__": # Inicializa las funciones.
    print("    ♥ Json y datos key and value del primer API: ") 
    print(datosAleatoriosDeGatos(url1)) # Imprime.
    print("    ♥ Json y datos key and value del segundo API: ")  
    print(actividadeAleatorias(url2))
    print("    ♥ Json y datos key and value del tercer API: ") 
    print(chistesAleatorios(url3))
# Out:
#     ♥ Json y datos key and value del primer API:
# fact : Miacis, the primitive ancestor of cats, was a small, tree-living creature of the late Eocene period, some 45 to 50 million years ago.
# length : 133
# {"fact":"Miacis, the primitive ancestor of cats, was a small, tree-living creature of the late Eocene period, some 45 to 50 million years ago.","length":133}
#     ♥ Json y datos key and value del segundo API:
# activity : Have a jam session with your friends
# type : music
# participants : 5
# price : 0.1
# link :
# key : 2715253
# accessibility : 0.3
# {"activity":"Have a jam session with your friends","type":"music","participants":5,"price":0.1,"link":"","key":"2715253","accessibility":0.3}
#     ♥ Json y datos key and value del tercer API:
# type : general
# setup : How many tickles does it take to tickle an octopus?
# punchline : Ten-tickles!
# id : 145
# {"type":"general","setup":"How many tickles does it take to tickle an octopus?","punchline":"Ten-tickles!","id":145}
